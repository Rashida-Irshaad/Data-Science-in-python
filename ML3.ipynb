# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Out:
# C:\Users\Administrator\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Administrator\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Administrator\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Administrator\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv('C:/Users/Administrator/Downloads/AmesHousing.csv')
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df2 = df[['MS SubClass','MS Zoning']]
df2
# Out:
#       MS SubClass MS Zoning
# 0              20        RL
# 1              20        RH
# 2              20        RL
# 3              20        RL
# 4              60        RL
# ...           ...       ...
# 2925           80        RL
# 2926           20        RL
# 2927           85        RL
# 2928           20        RL
# 2929           60        RL
#
# [2930 rows x 2 columns]

# %%
lee = LabelEncoder()

# %%
l = lee.fit_transform(df['MS SubClass'])
l
# Out:
# array([0, 0, 0, ..., 9, 0, 5], dtype=int64)

# %%
df2['MS Zoning_enc'] = lee.fit_transform(df['MS SubClass'])
df2
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       MS SubClass MS Zoning  MS Zoning_enc
# 0              20        RL              0
# 1              20        RH              0
# 2              20        RL              0
# 3              20        RL              0
# 4              60        RL              5
# ...           ...       ...            ...
# 2925           80        RL              8
# 2926           20        RL              0
# 2927           85        RL              9
# 2928           20        RL              0
# 2929           60        RL              5
#
# [2930 rows x 3 columns]

# %%
df['MS Zoning'].value_counts()
# Out:
# RL         2273
# RM          462
# FV          139
# RH           27
# C (all)      25
# A (agr)       2
# I (all)       2
# Name: MS Zoning, dtype: int64

# %%
df['SalePrice'].value_counts()
# Out:
# 135000    34
# 140000    33
# 130000    29
# 155000    28
# 145000    26
#           ..
# 256300     1
# 274725     1
# 332200     1
# 57625      1
# 169985     1
# Name: SalePrice, Length: 1032, dtype: int64

# %%
order  ={"Ex":4,'Go':3,'Typ':2,'Fa':1}

# %%
df2['MS SubClass_en']=df2['MS SubClass'].map(order)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#       MS SubClass MS Zoning  MS Zoning_enc  MS SubClass_en
# 0              20        RL              0             NaN
# 1              20        RH              0             NaN
# 2              20        RL              0             NaN
# 3              20        RL              0             NaN
# 4              60        RL              5             NaN
# ...           ...       ...            ...             ...
# 2925           80        RL              8             NaN
# 2926           20        RL              0             NaN
# 2927           85        RL              9             NaN
# 2928           20        RL              0             NaN
# 2929           60        RL              5             NaN
#
# [2930 rows x 4 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
data = pd.read_csv('C:/Users/Administrator/Downloads/AmesHousing.csv')
data
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
x = data.drop('SalePrice',axis = 1)
y = data['SalePrice']
print('x',x.shape)
print('y',y.shape)
# Out:
# x (2930, 81)
# y (2930,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 51)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2344, 81)
# (586, 81)
# (2344,)
# (586,)

# %%
iris = pd.read_csv('C:/Users/Administrator/Downloads/Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris = iris.drop('Id',axis = 1)
x= iris.drop('Species',axis = 1)
y = iris['Species']
print('x',x.shape)
print('y',y.shape)
# Out:
# x (150, 4)
# y (150,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 51)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (120,)
# (30, 4)
# (30,)

# %%
print(x_train)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 50             7.0           3.2            4.7           1.4
# 64             5.6           2.9            3.6           1.3
# 42             4.4           3.2            1.3           0.2
# 59             5.2           2.7            3.9           1.4
# 93             5.0           2.3            3.3           1.0
# ..             ...           ...            ...           ...
# 110            6.5           3.2            5.1           2.0
# 122            7.7           2.8            6.7           2.0
# 105            7.6           3.0            6.6           2.1
# 16             5.4           3.9            1.3           0.4
# 57             4.9           2.4            3.3           1.0
#
# [120 rows x 4 columns]

# %%
from  sklearn.preprocessing import StandardScaler

# %%
Sc = StandardScaler()

# %%
Sc.fit(x_train)
x_train_Sc = Sc.transform(x_train)
Sc.fit(x_test)
x_test_Sc = Sc.transform(x_test)

# %%
x_train_Sc = pd.DataFrame(x_train_Sc,columns = ['SepalLengthCm' ,'SepalWidthCm'  ,'PetalLengthCm' , 'PetalWidthCm'])
x_test_Sc = pd.DataFrame(x_test_Sc,columns = ['SepalLengthCm' ,'SepalWidthCm'  ,'PetalLengthCm' , 'PetalWidthCm'])

# %%
import seaborn as sns
sns.pairplot(x_train)

# %%
import seaborn as sns
sns.pairplot(x_train_Sc)
